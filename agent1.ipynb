# %% [markdown]
# **OLLAMA Models - Finalized**

# %%
#OLLAMA 7 Models -- Finalized for AGENT 1

import requests

# Ollama API base
OLLAMA_URL = "http://localhost:11434/api/generate"

# Models to test
models = [
    "mistral:instruct",
    "llama3",
    "falcon:instruct",
    "gemma:7b-instruct",
    "llama2:7b-chat",
    "mistral:latest",
    "qwen2.5:0.5b-instruct"
]

prd_instruction = """
You are a Product Manager. Convert the following Business Requirement Document (BRD) into a structured Product Requirement Document (PRD) with sections:
- Objectives
- Key Features
- Acceptance Criteria
- Integrations
- Reporting

BRD:
"""

# Sample BRD text (web app example)
brd_text = "We want to build a task management web application for our employees. Users should be able to create tasks, assign `them to team members, set deadlines, and mark tasks as complete. The app should send automated reminders for pending tasks. Managers need a dashboard to track task progress, view completed tasks, and analyze team performance. The application must have secure login, responsive design for both desktop and mobile, and role-based access (admin, manager, employee). Reports should be downloadable in CSV format. The system should be lightweight, fast, and integrate with our existing email system for notifications."

prompt = prd_instruction + brd_text

def query_model(model, prompt):
    """Send prompt to Ollama model and return response"""
    try:
        response = requests.post(OLLAMA_URL, json={
            "model": model,
            "prompt": prompt,
            "stream": False
        })
        response.raise_for_status()
        return response.json().get("response", "").strip()
    except Exception as e:
        return f"❌ Error with {model}: {str(e)}"

def score_output(output):
    """
    Score the PRD output for:
    1. Section presence
    2. Word length
    3. Accuracy: coverage of key BRD features
    """
    # 1️⃣ Section check
    sections = ["Objectives", "Key Features", "Acceptance Criteria", "Integrations", "Reporting"]
    section_score = sum(1 for sec in sections if sec.lower() in output.lower())

    # 2️⃣ Length check
    length = len(output.split())
    length_score = 1 if 300 <= length <= 600 else 0

    # 3️⃣ Accuracy check (simple keyword-based)
    key_features = [
        "task creation", "assign tasks", "deadlines", "reminders",
        "manager dashboard", "reports", "secure login",
        "role-based access", "responsive", "email integration"
    ]
    matched_features = sum(1 for feat in key_features if feat.lower() in output.lower())
    accuracy_score = matched_features / len(key_features)  # normalized 0–1

    # 4️⃣ Total score (structure + length + accuracy)
    total_score = section_score + length_score + accuracy_score * 4  # section+length max=6, accuracy max=4
    return total_score, section_score, length, accuracy_score

# Run models and store results
results = []

for model in models:
    print("="*60)
    print(f"🚀 Model: {model}")
    print("-"*60)
    output = query_model(model, prompt)
    print(output)
    total, sec_score, length, acc_score = score_output(output)
    print(f"✅ Total Score: {total:.2f}/10 | Sections: {sec_score}/5 | Length: {length} words | Accuracy: {acc_score*100:.0f}%\n")
    results.append((model, total))

# Rank models
results.sort(key=lambda x: x[1], reverse=True)
best_model = results[0][0]

print("="*60)
print(f"🏆 Best model for Agent 1: {best_model}")
# Out:
# ============================================================
# 🚀 Model: mistral:instruct
# ------------------------------------------------------------
# **Product Requirement Document (PRD)**
#
# **Title:** Task Management Web Application
#
# **Objectives:**
# 1. To streamline task management within the company.
# 2. To facilitate collaboration among team members by allowing task assignment and tracking.
# 3. To improve productivity by setting deadlines and sending automated reminders for pending tasks.
# 4. To provide managers with a dashboard to monitor task progress, view completed tasks, and analyze team performance.
# 5. To ensure secure access with role-based permissions (admin, manager, employee).
# 6. To make the application lightweight, fast, and responsive on both desktop and mobile devices.
# 7. To integrate the application with our existing email system for notifications.
# 8. To allow managers to download reports in CSV format.
#
# **Key Features:**
# 1. Task creation and editing
# 2. Assignment of tasks to team members
# 3. Setting deadlines for tasks
# 4. Marking tasks as complete
# 5. Automated reminders for pending tasks
# 6. Manager dashboard for tracking task progress, viewing completed tasks, and analyzing team performance
# 7. Secure login
# 8. Role-based access (admin, manager, employee)
# 9. Responsive design for both desktop and mobile devices
# 10. Integration with the existing email system for notifications
# 11. Reporting functionality with CSV export option
#
# **Acceptance Criteria:**
# 1. Users should be able to create, edit, assign, mark as complete, and delete tasks within the application.
# 2. Managers should be able to view all tasks assigned to their team members, including progress and completion status.
# 3. Automated reminders for pending tasks should be sent at the specified deadlines.
# 4. The manager dashboard should provide an overview of task progress, completed tasks, and team performance.
# 5. The application should only allow authorized users (admin or manager) to access certain features based on their roles.
# 6. The application should function correctly across multiple devices and screen sizes.
# 7. Integration with the existing email system for notifications should be seamless and reliable.
# 8. Reports should be downloadable in CSV format from the manager dashboard.
#
# **Integrations:**
# 1. Existing Email System (SMTP)
#
# **Reporting:**
# 1. Task progress reports
# 2. Completed task reports
# 3. Team performance reports in CSV format
# ✅ Total Score: 9.20/10 | Sections: 5/5 | Length: 336 words | Accuracy: 80%
#
# ============================================================
# 🚀 Model: llama3
# ------------------------------------------------------------
# Here is the Product Requirement Document (PRD) based on the Business Requirement Document (BRD):
#
# **Product Requirements Document (PRD)**
#
# **Objectives**
#
# The objective of this project is to develop a task management web application that enables employees to efficiently manage their tasks, collaborate with team members, and track progress. The application will provide managers with a centralized dashboard to monitor task completion rates, identify areas for improvement, and optimize team performance.
#
# **Key Features**
#
# 1. **Task Management**: Users can create, assign, set deadlines, and mark tasks as complete.
# 2. **Automated Reminders**: Send automated reminders for pending tasks to ensure timely completion.
# 3. **Manager Dashboard**: A centralized dashboard for managers to track task progress, view completed tasks, and analyze team performance.
# 4. **Role-Based Access**: Three role-based access levels: admin, manager, employee, with secure login and authentication.
# 5. **Responsive Design**: The application will have a responsive design for seamless usage on both desktop and mobile devices.
# 6. **Integration with Email System**: Integrate with the existing email system for notifications and task assignment.
# 7. **Reports**: Generate reports that are downloadable in CSV format to facilitate data analysis.
#
# **Acceptance Criteria**
#
# 1. Users can create, edit, and delete tasks.
# 2. Tasks can be assigned to team members, and their status updated accordingly.
# 3. Automated reminders are sent for pending tasks.
# 4. The manager dashboard displays task progress, completed tasks, and team performance metrics.
# 5. Role-based access controls ensure that each user has the appropriate level of access.
# 6. The application is responsive and accessible on both desktop and mobile devices.
# 7. Reports can be generated and downloaded in CSV format.
#
# **Integrations**
#
# 1. **Existing Email System**: Integrate with our existing email system for notifications, task assignment, and reminders.
# 2. **Other Systems**: Consider integrating with other systems (e.g., project management tools) to enhance the overall user experience.
#
# **Reporting**
#
# 1. **Task Completion Rates**: Generate reports on task completion rates by team member, manager, or department.
# 2. **Team Performance Metrics**: Track and analyze key performance metrics, such as task completion speed, productivity, and efficiency.
# 3. **Customizable Reports**: Allow users to customize report formats and content to suit their needs.
#
# By structuring the BRD into a PRD, we've identified clear objectives, features, acceptance criteria, integrations, and reporting requirements for the task management web application. This will help guide the development process and ensure that the final product meets the business requirements.
# ✅ Total Score: 8.80/10 | Sections: 5/5 | Length: 388 words | Accuracy: 70%
#
# ============================================================
# 🚀 Model: falcon:instruct
# ------------------------------------------------------------
# - Object:
# A task management web application.
# - Key Features:
# - Create tasks and assign them to team members.
# - Set deadlines and mark tasks as complete.
# - Automated reminders for pending tasks.
# - Manager dashboard for task progress and completed task view.
# - Role-based access.
# - Lightweight and fast.
# - Integrate with existing email system for notifications.
# - Accepting Criteria:
# - Access to tasks and project details should be secure and limited.
# - Ability to set deadlines and mark tasks as complete.
# - Manager dashboard and reports should be responsive.
# - Task management should be lightweight and fast.
# - Role-based access should be secure.
# - Integration with existing email system for notifications.
# - User
# ✅ Total Score: 3.40/10 | Sections: 1/5 | Length: 115 words | Accuracy: 60%
#
# ============================================================
# 🚀 Model: gemma:7b-instruct
# ------------------------------------------------------------
# ## Product Requirements Document (PRD)
#
# **Objectives:**
#
# - Enhance team productivity and efficiency through centralized task management.
# - Improve visibility and accountability of tasks across the team.
# - Automate task reminders and notifications.
# - Provide managers with data-driven insights on team performance.
#
# **Key Features:**
#
# **1. Task Management:**
# - Create tasks with titles, descriptions, and deadlines.
# - Assign tasks to team members.
# - Mark tasks as complete.
#
#
# **2. Reminders:**
# - Automatic email reminders for pending tasks.
# - Configurable reminder frequency and time.
#
#
# **3. Dashboard:**
# - Manager-specific dashboard with:
#     - Overview of completed tasks.
#     - Real-time progress tracking of remaining tasks.
#     - Team performance analytics.
#
#
# **4. Security and Access:**
# - Secure login with role-based access control:
#     - Admin: Full access to system configuration and data.
#     - Manager: Access to team management features and performance reports.
#     - Employee: Access to task management features.
#
#
# **Acceptance Criteria:**
#
# - Users can create and assign tasks successfully.
# - Deadline reminders are delivered on time and to the assigned recipients.
# - Dashboard displays completed tasks and team performance metrics.
# - Secure login system prevents unauthorized access.
# - Responsive design adjusts to different screen sizes.
# - CSV download option available for reports.
#
# **Integrations:**
#
# - Email system for automated notifications.
#
# **Reporting:**
#
# - Generate downloadable reports with:
#     - Task completion rate.
#     - Individual and team performance statistics.
#     - Trends and patterns in task management behavior.
# ✅ Total Score: 7.80/10 | Sections: 5/5 | Length: 223 words | Accuracy: 70%
#
# ============================================================
# 🚀 Model: llama2:7b-chat
# ------------------------------------------------------------
# Product Requirement Document (PRD)
#
# Objectives:
#
# * Develop a task management web application for employees to create, assign, and track tasks
# * Provide managers with a dashboard to monitor task progress, view completed tasks, and analyze team performance
# * Ensure secure login and role-based access for admin, manager, and employee users
# * Offer responsive design for both desktop and mobile devices
# * Provide automated reminders for pending tasks
# * Allow users to download reports in CSV format
#
# Key Features:
#
# * Task creation and assignment to team members
# * Set deadlines and mark tasks as complete
# * Automated reminders for pending tasks
# * Manager dashboard for task tracking, completed task viewing, and team performance analysis
# * Secure login and role-based access control
# * Responsive design for desktop and mobile devices
# * Integration with existing email system for notifications
#
# Acceptance Criteria:
#
# * Task creation and assignment must be possible through the web application
# * Deadlines must be settable and viewable by users
# * Automated reminders must be sent to users for pending tasks
# * Manager dashboard must provide clear visibility into task progress, completed tasks, and team performance
# * Secure login and role-based access control must be in place to protect user data
# * Web application must be responsive and accessible on both desktop and mobile devices
# * Integration with existing email system for notifications must be seamless and reliable
#
# Integrations:
#
# * Integration with existing email system for notifications
#
# Reporting:
#
# * Reports must be downloadable in CSV format
#
# Assumptions:
#
# * The application will be developed using a web-based technology stack (e.g., HTML, CSS, JavaScript, and a back-end framework)
# * The application will be hosted on a cloud-based server (e.g., Amazon Web Services or Microsoft Azure)
# * The existing email system will be used for notifications
#
# Dependencies:
#
# * Existing email system for notifications
#
# Risks:
#
# * Dependence on the reliability and security of the existing email system for notifications
# * Potential issues with integration between the web application and the email system
#
# Implementation Plan:
#
# 1. Research and planning (2 weeks)
# 	* Define scope and objectives
# 	* Identify key features and requirements
# 	* Develop a high-level project plan
# 2. Design and prototyping (4 weeks)
# 	* Create wireframes and mockups of the application
# 	* Conduct usability testing and gather feedback
# 	* Refine design and create a functional prototype
# 3. Development (12 weeks)
# 	* Develop the web application using a web-based technology stack
# 	* Integrate with existing email system for notifications
# 	* Test and iterate on designs and functionality
# 4. Testing and quality assurance (4 weeks)
# 	* Conduct thorough testing of the application
# 	* Gather feedback and make improvements
# 5. Deployment and launch (2 weeks)
# 	* Deploy the application to a cloud-based server
# 	* Conduct final testing and debugging
# 	* Launch the application to users
#
# Total duration: 20 weeks
# ✅ Total Score: 9.20/10 | Sections: 5/5 | Length: 461 words | Accuracy: 80%
#
# ============================================================
# 🚀 Model: mistral:latest
# ------------------------------------------------------------
# **Product Requirement Document (PRD)**
#
# **Title:** Task Management Web Application
#
# **Sections:**
# - Objectives
# - Key Features
# - Acceptance Criteria
# - Integrations
# - Reporting
#
# **Objectives:**
# 1. Facilitate efficient task assignment and management for our employees.
# 2. Enable managers to track progress, analyze team performance, and view completed tasks.
# 3. Implement secure login and role-based access (admin, manager, employee).
# 4. Ensure a responsive design for both desktop and mobile devices.
# 5. Optimize the system for speed and lightweight usage.
# 6. Integrate with our existing email system for notifications.
# 7. Provide downloadable reports in CSV format.
#
# **Key Features:**
# 1. Task creation and editing.
# 2. Assignment of tasks to team members.
# 3. Setting deadlines for tasks.
# 4. Marking tasks as complete.
# 5. Automated reminders for pending tasks.
# 6. Dashboard for managers to track task progress and view completed tasks.
# 7. Role-based access control (admin, manager, employee).
# 8. Secure login.
# 9. Responsive design for desktop and mobile devices.
# 10. Integration with the existing email system for notifications.
# 11. Downloadable reports in CSV format.
#
# **Acceptance Criteria:**
# 1. Users can create, edit, assign, mark as complete, and delete tasks.
# 2. Tasks have deadlines that are visible to assigned team members.
# 3. Automated reminders are sent for pending tasks.
# 4. Managers can access a dashboard to track task progress and view completed tasks.
# 5. The system provides secure login with role-based access (admin, manager, employee).
# 6. The application is responsive for both desktop and mobile devices.
# 7. Integration with the existing email system is seamless for notifications.
# 8. Reports can be downloaded in CSV format by managers.
# 9. The system operates at an acceptable speed and size.
#
# **Integrations:**
# 1. Existing Email System - For task reminders and notifications.
#
# **Reporting:**
# 1. Task progress reports for managers.
# 2. Completed tasks reports for managers.
# 3. Team performance analysis reports for managers.
# 4. Reports downloadable in CSV format.
# ✅ Total Score: 8.80/10 | Sections: 5/5 | Length: 305 words | Accuracy: 70%
#
# ============================================================
# 🚀 Model: qwen2.5:0.5b-instruct
# ------------------------------------------------------------
# ### Objectives
#
# 1. **Objective 1:** Build a task management web application that empowers employees to manage tasks efficiently.
# 2. **Objective 2:** Ensure the application supports users in creating, assigning tasks, setting deadlines, marking tasks as complete, and tracking their progress.
# 3. **Objective 3:** Provide automated reminders for pending tasks and allow managers to monitor task status and performance.
#
# ### Key Features
#
# 1. **User Interface (UI):**
#    - User-friendly interface for creating new tasks.
#    - Ability to assign tasks to team members.
#    - Set deadlines for each task.
#    - Mark tasks as "completed".
# 2. **Task Management:**
#    - Dashboard displaying pending tasks and their statuses.
#    - Task list with fields such as:
#      - Task name
#      - Team member(s) assigned
#      - Deadline
#      - Status (e.g., in progress, completed)
# 3. **Automation Features:**
#    - Automated reminders for task completion.
# 4. **Permissions & Roles:**
#    - Secure login with role-based access control (RBAC).
# 5. **Reporting:**
#    - Downloadable reports showing tasks by user, team, and date range.
# 6. **Security & Performance:**
#    - Ensures secure data transmission, responsive design for both desktop and mobile.
# 7. **User Experience:**
#    - Lightweight, fast, and integrated with existing email system for notifications.
#
# ### Acceptance Criteria
#
# 1. All users are able to create new tasks successfully.
# 2. Task assignments can be made to multiple team members.
# 3. Users have the capability to mark a task as "completed".
# 4. Dashboard displays pending tasks and their status.
# 5. Automated reminders for completed tasks.
# 6. Notifications from managers appear in the dashboard.
# 7. Reports are downloadable in CSV format.
#
# ### Integrations
#
# - **Email System:** The system should integrate with our existing email system, allowing users to send automated emails with reminders or task notifications.
# - **Task Management Web Application:** The app must be integrated seamlessly within the company's current task management platform.
#
# ### Reporting
#
# 1. Provide a user-friendly dashboard for analyzing task performance and team progress.
# 2. Downloadable reports showing tasks by user, team, and date range.
#
# These sections should help in structuring the detailed product requirements for building a task management web application that meets all of your specified objectives and key features.
# ✅ Total Score: 8.80/10 | Sections: 5/5 | Length: 346 words | Accuracy: 70%
#
# ============================================================
# 🏆 Best model for Agent 1: mistral:instruct

# %% [markdown]
# **BRD 2**

# %%
#OLLAMA 7 Models -- Finalized for AGENT 1

import requests

# Ollama API base
OLLAMA_URL = "http://localhost:11434/api/generate"

# Models to test
models = [
    "mistral:instruct",
    "llama3",
    "falcon:instruct",
    "gemma:7b-instruct",
    "llama2:7b-chat",
    "mistral:latest",
    "qwen2.5:0.5b-instruct"
]

prd_instruction = """
You are a Product Manager. Convert the following Business Requirement Document (BRD) into a structured Frontend Product Requirement Document (PRD) with sections:
- Objectives
- UI Components (list of screens and components)
- State Management Requirements (Redux slices, actions, reducers)
- Data Persistence (localStorage usage)
- User Roles & Access Control (if applicable)
- Acceptance Criteria (how the frontend should behave)

BRD:
"""

# Sample BRD text (web app example)
brd_text = """We want to build a personal portfolio website for showcasing an individual's projects and skills. The website should have the following sections: Home, About, Projects, Skills, and Contact. Users should be able to click through navigation links at the top of the page to move between sections smoothly (single-page scrolling). 
The Projects section should display project cards with images, titles, short descriptions, and buttons to view more details or visit external links (e.g., GitHub, Live Demo). 
The Contact section should include a simple form with fields for name, email, and message (no backend processing required, just UI). 
The design should be modern, responsive (desktop, tablet, mobile), and lightweight, with a visually appealing color scheme. 
Animations and transitions should be used for smooth user experience. 
There is no need for backend or database; this is a frontend-only project.
"""
prompt = prd_instruction + brd_text

def query_model(model, prompt):
    """Send prompt to Ollama model and return response"""
    try:
        response = requests.post(OLLAMA_URL, json={
            "model": model,
            "prompt": prompt,
            "stream": False
        })
        response.raise_for_status()
        return response.json().get("response", "").strip()
    except Exception as e:
        return f"❌ Error with {model}: {str(e)}"

def score_output(output):
    """
    Score the Frontend PRD output for:
    1. Section presence
    2. Word length
    3. Accuracy: coverage of key BRD features
    """
    # 1️⃣ Section check (frontend-specific)
    sections = [
        "Objectives", 
        "UI Components", 
        "State Management Requirements", 
        "Data Persistence", 
        "User Roles", 
        "Acceptance Criteria"
    ]
    section_score = sum(1 for sec in sections if sec.lower() in output.lower())

    # 2️⃣ Length check (keep same rule)
    length = len(output.split())
    length_score = 1 if 300 <= length <= 600 else 0

    # 3️⃣ Accuracy check (frontend features instead of BE stuff)
    key_features = [
        "task creation", "edit task", "delete task", "toggle complete",
        "assign tasks", "manager dashboard", "login", "role-based access",
        "localstorage", "notifications", "csv export", "responsive"
    ]
    matched_features = sum(1 for feat in key_features if feat.lower() in output.lower())
    accuracy_score = matched_features / len(key_features)  # normalized 0–1

    # 4️⃣ Total score (structure + length + accuracy)
    total_score = section_score + length_score + accuracy_score * 4  # section+length max=7, accuracy max=4
    return total_score, section_score, length, accuracy_score


# Run models and store results
results = []

for model in models:
    print("="*60)
    print(f"🚀 Model: {model}")
    print("-"*60)
    output = query_model(model, prompt)
    print(output)
    total, sec_score, length, acc_score = score_output(output)
    print(f"✅ Total Score: {total:.2f}/10 | Sections: {sec_score}/5 | Length: {length} words | Accuracy: {acc_score*100:.0f}%\n")
    results.append((model, total))

# Rank models
results.sort(key=lambda x: x[1], reverse=True)
best_model = results[0][0]

print("="*60)
print(f"🏆 Best model for Agent 1: {best_model}")
# Out:
# ============================================================
# 🚀 Model: mistral:instruct
# ------------------------------------------------------------
# **Frontend Product Requirement Document (PRD)**
#
# ---
#
# ### Objectives
#
# 1. Develop a personal portfolio website that showcases an individual's projects, skills, and contact information.
# 2. Ensure the website has seamless navigation with smooth single-page scrolling between sections (Home, About, Projects, Skills, Contact).
# 3. Design project cards for the Projects section to include images, titles, short descriptions, view more details buttons, and external links (e.g., GitHub, Live Demo).
# 4. Implement a simple contact form in the Contact section with fields for name, email, and message.
# 5. Create a modern, responsive, lightweight, and visually appealing design with an effective color scheme.
# 6. Utilize animations and transitions to enhance user experience.
# 7. Complete this project as a frontend-only endeavor without requiring a backend or database.
#
# ---
#
# ### UI Components
#
# #### Screens:
# 1. Home Screen
# 2. About Screen
# 3. Projects Screen (Project Card Component)
# 4. Skills Screen
# 5. Contact Screen (Contact Form)
#
# #### Components:
# 1. Navigation Bar
# 2. Hero Section
# 3. Project Card Component
# 4. Contact Form Component
# 5. Responsive Grid System
# 6. Animations and Transitions
#
# ---
#
# ### State Management Requirements
#
# #### Redux Slices & Actions:
# 1. Navigation Slice: Handles the visibility of each screen (Home, About, Projects, Skills, Contact).
# 2. Projects Slice: Manages the list of projects and their individual details.
# 3. Contact Form Slice: Tracks the state of the form fields.
#
# #### Reducers:
# 1. Navigation Reducer: Updates the current visible screen based on the action dispatched.
# 2. Projects Reducer: Handles actions related to project data (fetching, adding, removing).
# 3. Contact Form Reducer: Processes changes in form field values and form submission.
#
# ---
#
# ### Data Persistence
#
# The localStorage will be used for persisting the current visible screen upon page refresh. This ensures that users can easily return to their desired section after refreshing the page.
#
# ---
#
# ### User Roles & Access Control (if applicable)
#
# As this is a personal portfolio website, there are no specific user roles or access control requirements. However, consider making the site accessible for all users regardless of their device or browser.
#
# ---
#
# ### Acceptance Criteria
#
# 1. The website loads smoothly and displays the expected screens (Home, About, Projects, Skills, Contact) upon initial load.
# 2. Users can navigate between sections using the top navigation links with a single-page scrolling experience.
# 3. The Projects section displays project cards that include images, titles, short descriptions, view more details buttons, and external links (e.g., GitHub, Live Demo).
# 4. The Contact section includes a simple form for users to input their name, email, and message without any backend processing required.
# 5. The design is modern, responsive (desktop, tablet, mobile), lightweight, and visually appealing with an effective color scheme.
# 6. Animations and transitions are implemented throughout the site to provide a smooth user experience.
# 7. The website functions correctly in various browsers and on different devices, ensuring accessibility for all users.
# ✅ Total Score: 7.67/10 | Sections: 6/5 | Length: 466 words | Accuracy: 17%
#
# ============================================================
# 🚀 Model: llama3
# ------------------------------------------------------------
# Here is the converted Product Requirement Document (PRD) in a structured format:
#
# **Objectives**
#
# The objective of this project is to build a modern, responsive, and visually appealing personal portfolio website that showcases an individual's projects and skills. The website should provide a seamless user experience with smooth navigation and animations.
#
# **UI Components**
#
# * Home: A hero section with a background image/video, heading, and brief summary
# * About: A bio section with a profile picture, heading, and short description
# * Projects:
# 	+ Project cards with images, titles, short descriptions, and buttons to view more details or visit external links (e.g., GitHub, Live Demo)
# 	+ Pagination for displaying multiple projects
# * Skills: A list of skills with icons and brief descriptions
# * Contact: A simple form with fields for name, email, and message
#
# **State Management Requirements**
#
# * Redux setup with the following slices:
# 	+ ProjectsSlice: manages project data (title, description, image, etc.)
# 	+ ContactFormSlice: manages contact form state (name, email, message)
# * Actions:
# 	+ FetchProjectsAction: fetches project data from storage (localStorage) or API (if needed)
# 	+ UpdateContactFormDataAction: updates the contact form state
# * Reducers:
# 	+ ProjectsReducer: handles updating project data
# 	+ ContactFormReducer: handles updating the contact form state
#
# **Data Persistence**
#
# * Store project data in localStorage for fast access and retrieval
# * Use JSON.stringify() and JSON.parse() to serialize and deserialize project data, respectively
#
# **User Roles & Access Control**
#
# * No user roles or access control required as this is a single-user portfolio website with no login functionality.
#
# **Acceptance Criteria**
#
# 1. The website should have a smooth navigation experience using single-page scrolling.
# 2. The Projects section should display project cards with images, titles, short descriptions, and buttons to view more details or visit external links.
# 3. The Contact section should include a simple form with fields for name, email, and message.
# 4. The website should be responsive on desktop, tablet, and mobile devices.
# 5. Animations and transitions should be used for smooth user experience.
# 6. The website should load quickly (< 2 seconds) and have a lightweight footprint (< 500 KB).
# 7. The design should be visually appealing with a modern color scheme.
#
# Please let me know if you need any further modifications!
# ✅ Total Score: 8.00/10 | Sections: 6/5 | Length: 360 words | Accuracy: 25%
#
# ============================================================
# 🚀 Model: falcon:instruct
# ------------------------------------------------------------
# The following is a list of items that should be addressed when building the frontend of the website. These are in order of importance, from most to least important.
# User Interface
# 1. Make sure that the website is easy to navigate, with no unnecessary clutter.
# 2. Keep the interface clean and simple by using whitespace and appropriate spacing.
# 3. Use icons and other visual cues to guide the user and make the interface more intuitive.
# 4. Ensure that the interface is consistent and looks good on all devices.
# 5. Design the interface with accessibility in mind, so users with disabilities can use it.
# 6. Make sure that the interface is responsive and that it works on mobile devices.
# 7. Use appropriate fonts, colors, and other design elements to make the interface look good.
# 8. Make sure that the interface is optimized for performance.
# User Interface
# 1. Make sure that the website is easy to navigate, with no unnecessary clutter.
# 2. Keep the interface clean and simple by using whitespace and appropriate spacing.
# 3. Use icons and other visual cues to guide the user and make the interface more intuitive.
# 4. Ensure that the interface is consistent and looks good on all devices.
# 5. Design the interface with accessibility in mind, so users with disabilities can use it.
# 6. Make sure that the interface is responsive and that it works on mobile devices.
# 7. Use appropriate fonts, colors, and other design elements to make the interface look good.
# 8. Make sure that the interface is optimized for performance.
# User User Interface
# 1. Ensure that the interface is easy to navigate and that it looks good on all devices.
# 2. Use appropriate fonts, colors, and other design elements to make the interface look good.
# 3. Make sure that the interface is optimized for performance.
# 4. Keep the interface clean and simple by using whitespace and appropriate spacing.
# 5. Use icons and other visual cues to guide the user and make the interface more intuitive.
# 6. Make sure that the interface is consistent and looks good on all devices.
# 7. Design the interface with accessibility in mind, so users with disabilities can use it.
# 8. Ensure that the interface is responsive and that it works on mobile devices.
# User
# ✅ Total Score: 1.33/10 | Sections: 0/5 | Length: 376 words | Accuracy: 8%
#
# ============================================================
# 🚀 Model: gemma:7b-instruct
# ------------------------------------------------------------
# ## Frontend Product Requirement Document (PRD)
#
# **Objectives:**
#
# - Develop a modern, responsive personal portfolio website.
# - Showcase projects and skills effectively.
# - Provide a seamless user experience through single-page scrolling and animations.
#
# **UI Components:**
#
# **1. Home:**
# - Hero section with name and tagline
# - Brief overview of skills and projects
# - Navigation links to other sections
#
# **2. About:**
# - About me section with photo and bio
# - Highlights of skills and achievements
#
# **3. Projects:**
# - Project cards with:
#     - Image
#     - Title
#     - Short description
#     - Links to details or external sites
#
# **4. Skills:**
# - List of skills with icons and brief explanations
#
# **5. Contact:**
# - Simple form with:
#     - Name field
#     - Email field
#     - Message field
# - Submit button (no backend processing required)
#
# **State Management Requirements:**
#
# - Utilize Redux for state management.
# - Define slices for:
#     - Current section state (Home, About, etc.)
#     - Project selection state
#     - User input state (name, email, message)
#
# **Data Persistence:**
#
# - Store user input data in localStorage.
#
# **User Roles & Access Control:**
#
# - N/A (publicly accessible website)
#
# **Acceptance Criteria:**
#
# - The website loads and displays correctly on all major browsers and devices.
# - Navigation links enable smooth single-page scrolling.
# - Project cards display images, titles, descriptions, and links as expected.
# - The form validates user input and displays relevant messages.
# - Animations and transitions are visually appealing and enhance the user experience.
# - Data stored in localStorage persists after page refreshes.
# ✅ Total Score: 6.67/10 | Sections: 6/5 | Length: 239 words | Accuracy: 17%
#
# ============================================================
# 🚀 Model: llama2:7b-chat
# ------------------------------------------------------------
# Frontend Product Requirement Document (PRD)
#
# Objectives:
#
# * Build a personal portfolio website for showcasing an individual's projects and skills
# * Create a modern, responsive, and lightweight design
# * Implement smooth single-page scrolling navigation between sections
# * Display project cards with images, titles, short descriptions, and buttons to view more details or visit external links
# * Include a simple form for users to submit their name, email, and message in the Contact section (no backend processing required)
#
# UI Components:
#
# * Home page with navigation links to move between sections
# * About page with information about the individual's background and skills
# * Projects page with project cards displaying images, titles, short descriptions, and buttons for more details or external links
# * Skills page with a list of the individual's skills
# * Contact page with a simple form for users to submit their name, email, and message
#
# State Management Requirements:
#
# * Implement Redux slices for storing and managing project data
# * Define actions for navigating between sections and displaying project details
# * Create reducers for processing and storing project data
#
# Data Persistence:
#
# * Use localStorage to store project data locally on the user's device (no backend required)
#
# User Roles & Access Control (if applicable):
#
# * No user roles or access control requirements for this project
#
# Acceptance Criteria:
#
# * Smooth single-page scrolling navigation between sections
# * Project cards display images, titles, short descriptions, and buttons for more details or external links
# * Simple form on the Contact page allows users to submit their name, email, and message (no backend processing required)
# * Modern, responsive, and lightweight design
# * Animations and transitions are used for a smooth user experience
#
# Note: This is just an example PRD based on the provided BRD. The actual PRD may vary depending on specific requirements and constraints of the project.
# ✅ Total Score: 7.67/10 | Sections: 6/5 | Length: 300 words | Accuracy: 17%
#
# ============================================================
# 🚀 Model: mistral:latest
# ------------------------------------------------------------
# Frontend Product Requirement Document (PRD)
#
# **Objectives:**
# 1. Develop a personal portfolio website showcasing an individual's projects, skills, and contact information.
# 2. Ensure the website has a modern, responsive design with a visually appealing color scheme for a seamless user experience.
# 3. Implement smooth navigation between sections using single-page scrolling.
# 4. Design project cards that display images, titles, short descriptions, and buttons to view more details or visit external links.
# 5. Create a simple contact form within the Contact section for users to input name, email, and message without backend processing.
# 6. Implement animations and transitions to improve user experience.
# 7. Keep the design lightweight to ensure fast loading times across all devices.
#
# **UI Components:**
# 1. Home Screen
#     - Navigation bar with links to About, Projects, Skills, Contact sections
#     - Hero section showcasing a personal introduction or feature image
# 2. About Screen
#     - A brief overview of the individual's background and skills
#     - Social media icons for external links (LinkedIn, GitHub, etc.)
# 3. Projects Screen
#     - List of project cards displaying images, titles, short descriptions, and buttons to view more details or visit external links
# 4. Skills Screen
#     - List of skills with brief explanations or examples
# 5. Contact Screen
#     - A simple form for users to input name, email, message
#     - Submit button and success/error messages
# 6. Footer (optional)
#     - Copyright information, social media icons, and links to privacy policy and terms of service
#
# **State Management Requirements:**
# 1. Redux slices:
#    - Navigation (handling active navigation link)
#    - Projects (managing displayed project data)
#    - ContactForm (managing form state for the contact section)
# 2. Actions:
#    - ChangeActiveNavigationLink
#    - LoadProjectData
#    - SubmitContactForm
# 3. Reducers:
#    - navigationReducer
#    - projectsReducer
#    - contactFormReducer
#
# **Data Persistence:**
# 1. Use localStorage to save and retrieve user data (e.g., current navigation link) as needed.
#
# **User Roles & Access Control (if applicable):**
# There is no need for user roles or access control since this is a personal portfolio website for a single individual.
#
# **Acceptance Criteria:**
# 1. Users can navigate between sections using the top navigation bar without any issues.
# 2. Project cards display images, titles, short descriptions, and buttons to view more details or visit external links correctly.
# 3. The contact form accepts user input for name, email, and message and submits successfully without errors.
# 4. Success/error messages are displayed appropriately when the form is submitted.
# 5. The website has a modern, responsive design that works well on desktop, tablet, and mobile devices.
# 6. Animations and transitions are used effectively to improve user experience throughout the website.
# 7. The website loads quickly with minimal lag or delays.
# ✅ Total Score: 7.67/10 | Sections: 6/5 | Length: 426 words | Accuracy: 17%
#
# ============================================================
# 🚀 Model: qwen2.5:0.5b-instruct
# ------------------------------------------------------------
# ## Frontend Product Requirement Document
#
# ### Objectives:
# - **Object 1:** Build a modern and responsive personal portfolio website with a focus on showcasing projects, skills, and achievements.
# - **Object 2:** Ensure seamless navigation between sections using single-page scrolling for an optimal user experience.
# - **Object 3:** Design the project cards with images, titles, descriptions, buttons to view more details or external links.
# - **Object 4:** Implement a simple contact form with fields for name, email, and message.
# - **Object 5:** Use modern, responsive design principles for desktop, tablet, and mobile devices.
#
# ### UI Components:
# 1. Home Screen:
#    - Navigation Links: Home, About, Projects, Skills
#    - Cards: Project Image, Title, Short Description, Buttons to View More Details or External Links
#
# 2. About Section:
#    - Hero Card: Headline, Hero Image, Summary with Button
#    - Social Media: LinkedIn, GitHub, Twitter
#
# 3. Projects Section:
#    - Featured Projects: Card with Image, Title, Short Description, Link (GitHub)
#    - Project Details: Detailed card with detailed information about the project
#
# 4. Skills Section:
#    - Skill Cards: Basic skills, Advanced skills, Tools and Technologies
#    - Skills Button: Show more details or advanced features (e.g., GitHub API)
#
# 5. Contact Section:
#    - Form Fields: Name, Email, Message
#    - Buttons: Submit and Close
#
# ### State Management Requirements:
# - **Redux Slices:** Ensure components update correctly when state changes.
#   - `projectCardReducer`: Updates the display of a single project card based on its status or user action.
#   - `projectsReducer`: Updates the list of projects with new ones being added, deleted, or updated.
#
# ### Data Persistence (localStorage):
# - **Actions:**
#   - UpdateProject: Adds a new project to localStorage
#   - DeleteProject: Removes a project from localStorage
# - **Reducers:**
#   - `projectCardReducer`: Stores and updates card data in localStorage when necessary.
#
# ### User Roles & Access Control:
# - **User Roles:** Ensure user roles can access only their own projects, skills or contact forms.
# - **Access Control:**
#   - Only the "admin" role has read-only permissions for all pages.
#
# ### Acceptance Criteria:
# 1. **Navigation Links:** Users should be able to click through navigation links at the top of the page to move between sections smoothly using single-page scrolling.
# 2. **Card Display:** Clicking on a project card displays its image, title, brief description, and buttons for more details or external links.
# 3. **Contact Form:** Users can create and send a contact form with fields for name, email, and message.
# 4. **Responsive Design:** The website should be responsive across desktop, tablet, and mobile devices without requiring backend processing.
# 5. **Animations & Transitions:** Smooth user experience using modern design principles.
#
# ### Related Code:
# - Ensure necessary Redux actions and reducers are correctly implemented within the provided code snippet.
# ✅ Total Score: 7.67/10 | Sections: 6/5 | Length: 433 words | Accuracy: 17%
#
# ============================================================
# 🏆 Best model for Agent 1: llama3

# %% [markdown]
# **BRD 2 updated**

# %%
#OLLAMA 7 Models -- Finalized for AGENT 1

import requests

# Ollama API base
OLLAMA_URL = "http://localhost:11434/api/generate"

# Models to test
models = [
    "mistral:instruct",
    "llama3",
    "gemma:7b-instruct",
    "llama2:7b-chat",
    "mistral:latest",
    "qwen2.5:0.5b-instruct"
]

prd_instruction = """
You are a Product Manager, but keep your output minimal and developer-focused. 
Convert the following Business Requirement Document (BRD) into a concise Frontend Product Requirement Document (PRD). 

Rules:
- Be short and direct. 
- No long explanations or repeated sentences. 
- Only include details needed for developers to build the frontend. 
- Focus on structure, not prose. 

Your PRD must have these exact sections:
1. Objectives (1-3 bullet points max)
2. UI Screens & Components (list of screens and key UI components only)
3. State Management (list the slices/states required)
4. Data Persistence (only if applicable)
5. User Roles (if any, otherwise say 'None')
6. Acceptance Criteria (just the checklist of frontend behaviors)

Output should be structured and minimal.
BRD:
"""


# Sample BRD text (web app example)
brd_text = """We want to build a personal portfolio website for showcasing an individual's projects and skills. The website should have the following sections: Home, About, Projects, Skills, and Contact. Users should be able to click through navigation links at the top of the page to move between sections smoothly (single-page scrolling). 
The Projects section should display project cards with images, titles, short descriptions, and buttons to view more details or visit external links (e.g., GitHub, Live Demo). 
The Contact section should include a simple form with fields for name, email, and message (no backend processing required, just UI). 
The design should be modern, responsive (desktop, tablet, mobile), and lightweight, with a visually appealing color scheme. 
Animations and transitions should be used for smooth user experience. 
There is no need for backend or database; this is a frontend-only project.
"""
prompt = prd_instruction + brd_text

def query_model(model, prompt):
    """Send prompt to Ollama model and return response"""
    try:
        response = requests.post(OLLAMA_URL, json={
            "model": model,
            "prompt": prompt,
            "stream": False
        })
        response.raise_for_status()
        return response.json().get("response", "").strip()
    except Exception as e:
        return f"❌ Error with {model}: {str(e)}"
    
import re
import nltk
from nltk.corpus import stopwords
from collections import Counter

# # Download resources once
# nltk.download("punkt")
# nltk.download("stopwords")


def extract_key_features(brd_text, top_n=12):
    """Extract candidate key features (nouns/important words) from BRD text."""
    words = re.findall(r"\b\w+\b", brd_text.lower())
    stop_words = set(stopwords.words("english"))
    words = [w for w in words if w not in stop_words and len(w) > 2]
    
    # frequency-based keywords
    common = Counter(words).most_common(top_n)
    features = [word for word, _ in common]
    return features

def score_output(output, brd_text):
    """
    Score the Frontend PRD output for:
    1. Section presence
    2. Word length
    3. Accuracy: coverage of BRD features
    """
    # 1️⃣ Section check (new PRD format)
    sections = [
        "Objectives", 
        "UI Screens", 
        "State Management", 
        "Data Persistence", 
        "User Roles", 
        "Acceptance Criteria"
    ]
    section_score = sum(1 for sec in sections if sec.lower() in output.lower())

    # 2️⃣ Length check
    length = len(output.split())
    length_score = 1 if 80 <= length <= 250 else 0

    # 3️⃣ Dynamic Accuracy check
    key_features = extract_key_features(brd_text)
    matched_features = sum(1 for feat in key_features if feat in output.lower())
    accuracy_score = matched_features / len(key_features) if key_features else 0

    # 4️⃣ Final total score
    total_score = section_score + length_score + accuracy_score * 3
    return total_score, section_score, length, accuracy_score, key_features

# Run models and store results
results = []

for model in models:
    print("="*60)
    print(f"🚀 Model: {model}")
    print("-"*60)
    output = query_model(model, prompt)
    print(output)
    
    # pass brd_text here 👇
    total, sec_score, length, acc_score, key_features = score_output(output, brd_text)
    
    print(f"✅ Total Score: {total:.2f}/10 | Sections: {sec_score}/5 | Length: {length} words | Accuracy: {acc_score*100:.0f}%")
    print(f"🔑 Extracted Features: {key_features}\n")
    results.append((model, total))

# Rank models
results.sort(key=lambda x: x[1], reverse=True)
best_model = results[0][0]

print("="*60)
print(f"🏆 Best model for Agent 1: {best_model}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CDS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CDS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ============================================================
# 🚀 Model: mistral:instruct
# ------------------------------------------------------------
# Title: Personal Portfolio Website Frontend PRD
#
# 1. Objectives
#    - Implement modern, responsive design (desktop, tablet, mobile)
#    - Create single-page scrolling navigation links
#    - Display visually appealing color scheme
#    - Incorporate smooth animations and transitions
#
# 2. UI Screens & Components
#    - Home Screen
#    - About Screen
#    - Projects Screen (Project Card: image, title, short description, view more details button, external link button)
#    - Skills Screen
#    - Contact Screen (Simple Form: name, email, message input fields)
#
# 3. State Management
#    - Navigation state
#    - Active screen/component state
#    - Project card states (hover, click)
#    - Form field states (focus, blur, validation error)
#
# 4. Data Persistence (Not applicable; frontend-only project)
#
# 5. User Roles
#    - None
#
# 6. Acceptance Criteria
#    - Navigation links allow smooth scrolling between sections
#    - Project cards display images, titles, short descriptions, and navigation buttons
#    - Contact form fields are functional and visually appealing
#    - Design is modern, responsive, lightweight, and visually appealing
#    - Animations and transitions enhance the user experience
# ✅ Total Score: 9.25/10 | Sections: 6/5 | Length: 158 words | Accuracy: 75%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🚀 Model: llama3
# ------------------------------------------------------------
# Here is the converted PRD:
#
# **Objectives**
#
# • Build a personal portfolio website with 5 main sections: Home, About, Projects, Skills, and Contact
# • Implement single-page scrolling navigation
# • Create a modern, responsive, and lightweight design
#
# **UI Screens & Components**
#
# • Home screen
# • About screen
# • Projects screen (with project cards)
# • Skills screen
# • Contact form
# • Project card (with image, title, description, and buttons)
#
# **State Management**
#
# • Navigation state: current section
# • Project details state: expanded/collapsed
#
# **Data Persistence**
#
# None (frontend-only project)
#
# **User Roles**
#
# None
#
# **Acceptance Criteria**
#
# • Navigation links at the top of the page allow smooth scrolling between sections
# • Projects screen displays project cards with images, titles, descriptions, and buttons
# • Contact form includes fields for name, email, and message
# • Design is modern, responsive, and lightweight
# • Animations and transitions are used for a smooth user experience
# ✅ Total Score: 9.50/10 | Sections: 6/5 | Length: 142 words | Accuracy: 83%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🚀 Model: gemma:7b-instruct
# ------------------------------------------------------------
# ## Frontend Product Requirement Document (PRD)
#
# **Objectives:**
#
# - Create a modern, responsive portfolio website.
# - Showcase projects and skills using interactive elements.
# - Provide a seamless user experience with single-page scrolling.
#
# **UI Screens & Components:**
#
# - Home
# - About
# - Projects (project cards with image, title, description, view/live link buttons)
# - Skills
# - Contact (name, email, message form)
#
# **State Management:**
#
# - Navigation links state (active/inactive)
# - Project card selection state
# - Input field state (name, email, message)
#
# **Data Persistence:**
#
# - N/A (frontend-only project)
#
# **User Roles:**
#
# - N/A
#
# **Acceptance Criteria:**
#
# - Navigation links change color when active.
# - Project cards can be clicked to expand details.
# - Input fields have appropriate placeholder text.
# - Form submission triggers visual feedback.
# - Website is responsive across desktop, tablet, and mobile devices.
# - Animations and transitions are smooth and visually appealing.
# ✅ Total Score: 8.75/10 | Sections: 6/5 | Length: 137 words | Accuracy: 58%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🚀 Model: llama2:7b-chat
# ------------------------------------------------------------
# Frontend Product Requirement Document (PRD)
#
# Objectives:
#
# * Create a modern, responsive, and lightweight personal portfolio website for an individual to showcase projects and skills.
# * Ensure smooth single-page scrolling navigation between sections.
# * Provide a visually appealing color scheme and use animations/transitions for a smooth user experience.
#
# UI Screens & Components:
#
# * Home page with a hero section and navigation links to other sections.
# * About page with a brief bio and contact information.
# * Projects page with project cards displaying images, titles, short descriptions, and buttons to view more details or external links (e.g., GitHub, Live Demo).
# * Skills page with a list of skills and a brief description of each.
# * Contact page with a simple form for users to submit their name, email, and message.
#
# State Management:
#
# * Store user navigation history for smooth single-page scrolling.
#
# Data Persistence: None
#
# User Roles:
# None
#
# Acceptance Criteria (Frontend Behaviors):
#
# * Smooth navigation between sections using single-page scrolling.
# * Visually appealing color scheme and animations/transitions throughout the website.
# * Project cards displayed on the Projects page with images, titles, short descriptions, and buttons to view more details or external links.
# * Simple form displayed on the Contact page for users to submit their name, email, and message.
# * Responsive design for desktop, tablet, and mobile devices.
# ✅ Total Score: 9.25/10 | Sections: 6/5 | Length: 215 words | Accuracy: 75%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🚀 Model: mistral:latest
# ------------------------------------------------------------
# Title: Personal Portfolio Website Frontend PRD
#
# 1. Objectives:
#    - Develop a modern, responsive (desktop, tablet, mobile) portfolio website showcasing projects and skills.
#    - Implement smooth single-page scrolling navigation links for seamless user experience.
#    - Design a visually appealing color scheme with lightweight performance.
#
# 2. UI Screens & Components:
#    - Home
#    - About
#    - Projects (Project cards: image, title, short description, view more details/visit external link buttons)
#    - Skills
#    - Contact (Name, Email, Message form)
#
# 3. State Management:
#    - Navigation state
#    - Active section state
#    - Project card hover state
#
# 4. Data Persistence (Not applicable as it's a frontend-only project)
#
# 5. User Roles: None
#
# 6. Acceptance Criteria:
#    - Smooth single-page scrolling navigation links between sections.
#    - Functional project cards with clickable buttons for viewing more details or visiting external links.
#    - Properly functioning contact form without backend processing.
#    - Modern and responsive design with a visually appealing color scheme.
#    - Animations and transitions for smooth user experience.
# ✅ Total Score: 9.50/10 | Sections: 6/5 | Length: 156 words | Accuracy: 83%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🚀 Model: qwen2.5:0.5b-instruct
# ------------------------------------------------------------
# Objectives:
# 1. Showcase projects and skills of the individual's portfolio on the website.
# 2. Enable users to browse through different sections of the portfolio smoothly using single-page scrolling.
# 3. Provide an interactive form with fields for name, email, and message.
#
# UI Screens & Components:
#
# - Home page: Navigation bar at top, Projects section in center (single-page scrolling)
# - About: Section with brief introduction, skills, projects, etc., displayed as a hero card
# - Projects: Displaying project cards with images, titles, descriptions, and buttons to open more details or external links.
# - Skills: List of skills with icons next to each skill.
#
# State Management:
#
# - Users should be able to access the Home page and navigate through sections seamlessly using single-page scrolling.
# - The Contact section will use a simple form without backend processing for easy user interaction.
#
# Data Persistence:
#
# - No data persistence is required. The frontend only handles UI updates, no backend or database are needed.
#
# User Roles:
# None
#
# Acceptance Criteria:
#
# 1. Users can access the Home page and navigate smoothly through different sections.
# 2. Projects cards display image, title, description, and buttons for more details.
# 3. Users should be able to input their name, email address, and message in the Contact section form without backend processing.
# 4. The navigation links within each section are single-page scrolling.
# 5. The website follows modern design principles, is responsive across desktops, tablets, and mobile devices.
# 6. The website has a visually appealing color scheme with animations and transitions for smooth user experience.
#
# The project details provided include the business requirement document (BRD), which we have converted into a concise frontend product requirement document (PRD) using minimal language suitable for developer-friendly outputs.
# ✅ Total Score: 8.50/10 | Sections: 6/5 | Length: 278 words | Accuracy: 83%
# 🔑 Extracted Features: ['projects', 'website', 'skills', 'sections', 'contact', 'links', 'page', 'section', 'project', 'backend', 'want', 'build']
#
# ============================================================
# 🏆 Best model for Agent 1: llama3

# %% [markdown]
# mistral:instruct = 18.1M
# LLaMA 3 8B Instruct = 10.5M
# Falcon-7B Instruct = 122
# "gemma:7b-instruct" = 5.2M
# qwen2.5:0.5b-instruct = 12.6M
# "llama2:7b-chat"
# "mistral:latest"

# %% [markdown]
# **HF Models not accurate**

# %% [markdown]
# **Using langchain framework for building agent 1**

# %%
# # Using langchain framework for building agent 1
# from langchain_community.llms import Ollama
# from langchain.prompts import PromptTemplate
# from langchain.chains import LLMChain

# # 1. Define models
# models = [
#     "mistral:instruct",
#     "llama3",
#     "falcon:instruct",
#     "gemma:7b-instruct",
#     "llama2:7b-chat",
#     "mistral:latest",
#     "qwen2.5:0.5b-instruct"
# ]

# # 2. Instruction template
# prd_instruction = """
# You are a Product Manager. Convert the following Business Requirement Document (BRD) into a structured Product Requirement Document (PRD) with sections:
# - Objectives
# - Key Features
# - Acceptance Criteria
# - Integrations
# - Reporting

# BRD: {brd_text}
# """

# # 3. BRD input
# brd_text = """We want to build a task management web application for our employees.
# Users should be able to create tasks, assign them to team members, set deadlines,
# and mark tasks as complete. The app should send automated reminders for pending tasks.
# Managers need a dashboard to track task progress, view completed tasks, and analyze team performance.
# The application must have secure login, responsive design for both desktop and mobile,
# and role-based access (admin, manager, employee). Reports should be downloadable in CSV format.
# The system should be lightweight, fast, and integrate with our existing email system for notifications.
# """

# # 4. Scoring function (same logic)
# def score_output(output):
#     sections = ["Objectives", "Key Features", "Acceptance Criteria", "Integrations", "Reporting"]
#     section_score = sum(1 for sec in sections if sec.lower() in output.lower())

#     length = len(output.split())
#     length_score = 1 if 300 <= length <= 600 else 0

#     key_features = [
#         "task creation", "assign tasks", "deadlines", "reminders",
#         "manager dashboard", "reports", "secure login",
#         "role-based access", "responsive", "email integration"
#     ]
#     matched_features = sum(1 for feat in key_features if feat.lower() in output.lower())
#     accuracy_score = matched_features / len(key_features)

#     total_score = section_score + length_score + accuracy_score * 4
#     return total_score, section_score, length, accuracy_score

# # 5. Run through LangChain wrapper
# results = []

# for model in models:
#     print("="*60)
#     print(f"🚀 Model: {model}")
#     print("-"*60)

#     llm = Ollama(model=model)
#     prompt = PromptTemplate(template=prd_instruction, input_variables=["brd_text"])
#     chain = LLMChain(llm=llm, prompt=prompt)

#     try:
#         output = chain.run(brd_text=brd_text).strip()
#         print(output)

#         total, sec_score, length, acc_score = score_output(output)
#         print(f"✅ Total Score: {total:.2f}/10 | Sections: {sec_score}/5 | Length: {length} words | Accuracy: {acc_score*100:.0f}%\n")
#         results.append((model, total))

#     except Exception as e:
#         print(f"❌ Error with {model}: {e}")

# # 6. Rank models
# results.sort(key=lambda x: x[1], reverse=True)
# best_model = results[0][0]

# print("="*60)
# print(f"🏆 Best model for Agent 1: {best_model}")
